# %% [markdown]
# # Probability exercises

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
#import libraries
import random
import numpy

#Funtion to roll the dice.
dice1 = 0
dice2 = 0

def diceRoller():
    counter = 0
    for _ in range(1000):
        dice1 = random.randint(1,6)
        dice2 = random.randint(1,6)
        score = dice1 + dice2
        if (score > 7 or score % 2 == 0):
            counter += 1
    return counter / 1000

print(f"The probability that from rolling a couple of dices a thousand times the obtained score is even or greater than 7 is of {diceRoller()*100}%")
# Out:
# The probability that from rolling a couple of dices a thousand times the obtained score is even or greater than 7 is of 65.5%

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
#import libraries
import random
import numpy as np


d = {}

for i in range(60):
    if i < 10:
        d[i] = 'White'
    elif i > 9 and i < 30:
        d[i] = 'Red'
    else:
        d[i] = 'Green'  
  
        
#Initialize important variables
picked = ''
n_simulations = 1000
comb1 = 0
comb2 = 0


for i in range(n_simulations):
    color_list = []
    #make a list of the colors that we choose
    for j in range(5):
        color_list.append(d[random.randint(0,59)])
    
    #Convert it to a numpy array
    color_arr = numpy.array(color_list)

    #find the number of each taht we picked
    white_count = np.count_nonzero(color_arr == 'White')
    red_count = np.count_nonzero(color_arr == 'Red')
    green_count = np.count_nonzero(color_arr == 'Green')
    
    #Keep track if the combination met the criteria
    if (white_count == 3 and red_count == 2):
        comb1 += 1
    if (white_count == 5 or red_count == 5 or green_count == 5):
        comb2 += 1
    
    
    
#print 'the probability of 3 white and 2 red is' in percentage
print(f"The probability of 3 white and 2 red is of {comb1/10}%")
#print 'the probability of all the same color is' in percentage
print(f"The probability of all balls the same color is of {comb2/10}%")
# Out:
# The probability of 3 white and 2 red is of 0.5%
# The probability of all balls the same color is of 4.2%
